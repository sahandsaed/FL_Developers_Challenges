# %%
import pandas as pd

df_1 =pd.read_csv('-1_Topics_data(1).csv') ## You might need to change the directory
open_count_df1 = df_1[df_1['state'] == 'open'].shape[0]
closed_count_df1 = df_1[df_1['state'] == 'closed'].shape[0]

unresolved_issues_percentage = (open_count_df1)/(open_count_df1+closed_count_df1)*100

# Ensure datetime format
df_1['created_at'] = pd.to_datetime(df_1['created_at'])
df_1['closed_at'] = pd.to_datetime(df_1['closed_at'])

# Filter rows where the issue is closed
closed_df_1 = df_1[df_1['closed_at'].notna()]

# # Calculate time to close
closed_df_1['time_to_close'] = (closed_df_1['closed_at'] - closed_df_1['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_1['time_to_close'].median()

print('T1')
print(median_time_to_close)

print(unresolved_issues_percentage)



df_2 =pd.read_csv('0_Topics_data(1).csv') ## You might need to change the directory
open_count_df2 = df_2[df_2['state'] == 'open'].shape[0]
closed_count_df2 = df_2[df_2['state'] == 'closed'].shape[0]

unresolved_issues_percentage = (open_count_df2)/(open_count_df2+closed_count_df2)*100

# Ensure datetime format
df_2['created_at'] = pd.to_datetime(df_2['created_at'])
df_2['closed_at'] = pd.to_datetime(df_2['closed_at'])

# Filter rows where the issue is closed
closed_df_2 = df_2[df_2['closed_at'].notna()]

# # Calculate time to close
closed_df_2['time_to_close'] = (closed_df_2['closed_at'] - closed_df_2['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_2['time_to_close'].median()
print('T2')
print(median_time_to_close)

print(unresolved_issues_percentage)



df_3 =pd.read_csv('1_Topics_data(1).csv') ## You might need to change the directory
open_count_df3 = df_3[df_3['state'] == 'open'].shape[0]
closed_count_df3 = df_3[df_3['state'] == 'closed'].shape[0]

unresolved_issues_percentage_3 = (open_count_df3)/(open_count_df3+closed_count_df3)*100

# Ensure datetime format
df_3['created_at'] = pd.to_datetime(df_3['created_at'])
df_3['closed_at'] = pd.to_datetime(df_3['closed_at'])

# Filter rows where the issue is closed
closed_df_3 = df_3[df_3['closed_at'].notna()]

# # Calculate time to close
closed_df_3['time_to_close'] = (closed_df_3['closed_at'] - closed_df_3['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_3['time_to_close'].median()
print('T3')
print(median_time_to_close)

print(unresolved_issues_percentage_3)


##Visual and Branding Enhancements
df_4 =pd.read_csv('2_Topics_data(1).csv') ## You might need to change the directory
open_count_df4 = df_4[df_4['state'] == 'open'].shape[0]
closed_count_df4 = df_4[df_4['state'] == 'closed'].shape[0]

unresolved_issues_percentage_4 = (open_count_df4)/(open_count_df4+closed_count_df4)*100

# Ensure datetime format
df_4['created_at'] = pd.to_datetime(df_4['created_at'])
df_4['closed_at'] = pd.to_datetime(df_4['closed_at'])

# Filter rows where the issue is closed
closed_df_4 = df_4[df_4['closed_at'].notna()]

# # Calculate time to close
closed_df_4['time_to_close'] = (closed_df_4['closed_at'] - closed_df_4['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_4['time_to_close'].median()
print('T4')
print(median_time_to_close)

print(unresolved_issues_percentage_4)


# Automated Performance and Tool Update Integration
df_5 =pd.read_csv('3_Topics_data(1).csv') ## You might need to change the directory
open_count_df5 = df_5[df_5['state'] == 'open'].shape[0]
closed_count_df5 = df_5[df_5['state'] == 'closed'].shape[0]

unresolved_issues_percentage_5 = (open_count_df5)/(open_count_df5+closed_count_df5)*100

# Ensure datetime format
df_5['created_at'] = pd.to_datetime(df_5['created_at'])
df_5['closed_at'] = pd.to_datetime(df_5['closed_at'])

# Filter rows where the issue is closed
closed_df_5 = df_5[df_5['closed_at'].notna()]

# # Calculate time to close
closed_df_5['time_to_close'] = (closed_df_5['closed_at'] - closed_df_5['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_5['time_to_close'].median()
print('T5')
print(median_time_to_close)

print(unresolved_issues_percentage_5)

df_6 =pd.read_csv('4_Topics_data(1).csv')
open_count_df6 = df_6[df_6['state'] == 'open'].shape[0]
closed_count_df6 = df_6[df_6['state'] == 'closed'].shape[0]

unresolved_issues_percentage_6 = (open_count_df6)/(open_count_df6+closed_count_df6)*100

# Ensure datetime format
df_6['created_at'] = pd.to_datetime(df_6['created_at'])
df_6['closed_at'] = pd.to_datetime(df_6['closed_at'])

# Filter rows where the issue is closed
closed_df_6 = df_6[df_6['closed_at'].notna()]

# # Calculate time to close
closed_df_6['time_to_close'] = (closed_df_6['closed_at'] - closed_df_6['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_6['time_to_close'].median()
print('T6')
print(median_time_to_close)

print(unresolved_issues_percentage_6)

## Managing Releases
df_7 =pd.read_csv('5_Topics_data(1).csv')
open_count_df7 = df_7[df_7['state'] == 'open'].shape[0]
closed_count_df7 = df_7[df_7['state'] == 'closed'].shape[0]

unresolved_issues_percentage_7 = (open_count_df7)/(open_count_df7+closed_count_df7)*100

# Ensure datetime format
df_7['created_at'] = pd.to_datetime(df_7['created_at'])
df_7['closed_at'] = pd.to_datetime(df_7['closed_at'])

# Filter rows where the issue is closed
closed_df_7 = df_7[df_7['closed_at'].notna()]

# # Calculate time to close
closed_df_7['time_to_close'] = (closed_df_7['closed_at'] - closed_df_7['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_7['time_to_close'].median()
print('T7')
print(median_time_to_close)

print(unresolved_issues_percentage_7)


#Browser Compatibility and HDFS Integration Issues
df_8 =pd.read_csv('6_Topics_data(1).csv')
open_count_df8 = df_8[df_8['state'] == 'open'].shape[0]
closed_count_df8 = df_8[df_8['state'] == 'closed'].shape[0]

unresolved_issues_percentage_8 = (open_count_df8)/(open_count_df8+closed_count_df8)*100

# Ensure datetime format
df_8['created_at'] = pd.to_datetime(df_8['created_at'])
df_8['closed_at'] = pd.to_datetime(df_8['closed_at'])

# Filter rows where the issue is closed
closed_df_8 = df_8[df_8['closed_at'].notna()]

# # Calculate time to close
closed_df_8['time_to_close'] = (closed_df_8['closed_at'] - closed_df_8['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_8['time_to_close'].median()
print('T8')
print(median_time_to_close)

print(unresolved_issues_percentage_8)



df_9 =pd.read_csv('7_Topics_data(1).csv')
open_count_df9 = df_9[df_9['state'] == 'open'].shape[0]
closed_count_df9 = df_9[df_9['state'] == 'closed'].shape[0]

unresolved_issues_percentage_9 = (open_count_df9)/(open_count_df9+closed_count_df9)*100

# Ensure datetime format
df_9['created_at'] = pd.to_datetime(df_9['created_at'])
df_9['closed_at'] = pd.to_datetime(df_9['closed_at'])

# Filter rows where the issue is closed
closed_df_9 = df_9[df_9['closed_at'].notna()]

# # Calculate time to close
closed_df_9['time_to_close'] = (closed_df_9['closed_at'] - closed_df_9['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_9['time_to_close'].median()
print('T9')
print(median_time_to_close)

print(unresolved_issues_percentage_9)


df_10 =pd.read_csv('8_Topics_data.csv')
open_count_df10 = df_10[df_10['state'] == 'open'].shape[0]
closed_count_df10 = df_10[df_10['state'] == 'closed'].shape[0]

unresolved_issues_percentage_10 = (open_count_df10)/(open_count_df10+closed_count_df10)*100

# Ensure datetime format
df_10['created_at'] = pd.to_datetime(df_10['created_at'])
df_10['closed_at'] = pd.to_datetime(df_10['closed_at'])

# Filter rows where the issue is closed
closed_df_10 = df_10[df_10['closed_at'].notna()]

# # Calculate time to close
closed_df_10['time_to_close'] = (closed_df_10['closed_at'] - closed_df_10['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_10['time_to_close'].median()
print('T10')
print(median_time_to_close)

print(unresolved_issues_percentage_10)

df_11 =pd.read_csv('9_Topics_data.csv')
open_count_df11 = df_11[df_11['state'] == 'open'].shape[0]
closed_count_df11 = df_11[df_11['state'] == 'closed'].shape[0]

unresolved_issues_percentage_11 = (open_count_df11)/(open_count_df11+closed_count_df11)*100

# Ensure datetime format
df_11['created_at'] = pd.to_datetime(df_11['created_at'])
df_11['closed_at'] = pd.to_datetime(df_11['closed_at'])

# Filter rows where the issue is closed
closed_df_11 = df_11[df_11['closed_at'].notna()]

# # Calculate time to close
closed_df_11['time_to_close'] = (closed_df_11['closed_at'] - closed_df_11['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_11['time_to_close'].median()
print('T11')
print(median_time_to_close)

print(unresolved_issues_percentage_11)


df_12 =pd.read_csv('10_Topics_data.csv')
open_count_df12 = df_12[df_12['state'] == 'open'].shape[0]
closed_count_df12 = df_12[df_12['state'] == 'closed'].shape[0]

unresolved_issues_percentage_12 = (open_count_df12)/(open_count_df12+closed_count_df12)*100

# Ensure datetime format
df_12['created_at'] = pd.to_datetime(df_12['created_at'])
df_12['closed_at'] = pd.to_datetime(df_12['closed_at'])

# Filter rows where the issue is closed
closed_df_12 = df_12[df_12['closed_at'].notna()]

# # Calculate time to close
closed_df_12['time_to_close'] = (closed_df_12['closed_at'] - closed_df_12['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_12['time_to_close'].median()
print('T12')
print(median_time_to_close)

print(unresolved_issues_percentage_12)

df_13 =pd.read_csv('11_Topics_data.csv')
open_count_df13 = df_13[df_13['state'] == 'open'].shape[0]
closed_count_df13 = df_13[df_13['state'] == 'closed'].shape[0]

unresolved_issues_percentage_13 = (open_count_df13)/(open_count_df13+closed_count_df13)*100

# Ensure datetime format
df_13['created_at'] = pd.to_datetime(df_13['created_at'])
df_13['closed_at'] = pd.to_datetime(df_13['closed_at'])

# Filter rows where the issue is closed
closed_df_13 = df_13[df_13['closed_at'].notna()]

# # Calculate time to close
closed_df_13['time_to_close'] = (closed_df_13['closed_at'] - closed_df_13['created_at']).dt.total_seconds() / 3600  # in hours

median_time_to_close = closed_df_13['time_to_close'].median()
print('T13')
print(median_time_to_close)

print(unresolved_issues_percentage_13)
# Out:
# /tmp/ipython-input-2698290042.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_df_1['time_to_close'] = (closed_df_1['closed_at'] - closed_df_1['created_at']).dt.total_seconds() / 3600  # in hours
# /tmp/ipython-input-2698290042.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   closed_df_2['time_to_close'] = (closed_df_2['closed_at'] - closed_df_2['created_at']).dt.total_seconds() / 3600  # in hours
# /tmp/ipython-input-2698290042.py:66: SettingWithCopyWarning:
# ...
